# %% [markdown]
# # 04 - Macro Event Study
# Build -5/+10 trading-day response paths around illustrative CPI events. Replace `events.csv` with verified time-stamped release data for real research.

# %%
from pathlib import Path
import sys
ROOT = Path.cwd().resolve().parents[0] if Path.cwd().name == 'notebooks' else Path.cwd().resolve()
sys.path.insert(0, str(ROOT))
from src.data_loader import load_sample_levels, load_events
from src.event_study import run_event_study, aggregate_event_paths, event_snapshot
from src.charts import event_path_chart

# %%
levels = load_sample_levels()
events = load_events().query("category == 'US CPI'")
study = run_event_study(levels, events, ['SPY', 'XLF', 'WTI', 'USDCAD', 'USDKRW', 'US10Y'], pre_days=5, post_days=10)
study.head()

# %%
aggregate = aggregate_event_paths(study)
event_path_chart(aggregate).show()

# %%
event_snapshot(study, (0, 1, 5, 10)).style.format({c: '{:+.2f}' for c in ['Day +0', 'Day +1', 'Day +5', 'Day +10']})

# %% [markdown]
# Next extensions: split positive and negative surprises, winsorize outliers, prevent overlapping windows, and report bootstrap confidence intervals.
