# %% [markdown]
# # 02 - Macro and Cross-Asset Analysis
# Analyze levels, unit-aware moves, full-sample correlations, and time-varying WTI/USD-CAD sensitivity.

# %%
from pathlib import Path
import sys
ROOT = Path.cwd().resolve().parents[0] if Path.cwd().name == 'notebooks' else Path.cwd().resolve()
sys.path.insert(0, str(ROOT))
from src.data_loader import load_sample_levels
from src.indicators import latest_change_table, correlation_matrix, rolling_correlation
from src.charts import performance_chart, rolling_correlation_chart

# %%
levels = load_sample_levels().loc['2018':]
latest_change_table(levels).style.format({'level': '{:,.2f}', '1D': '{:+.2f}', '1W': '{:+.2f}', '1M': '{:+.2f}'})

# %%
correlation_matrix(levels[['SPY', 'XLF', 'XLE', 'WTI', 'USDCAD', 'USDKRW', 'US10Y']]).round(2)

# %%
rolling_correlation_chart(levels, 'WTI', 'USDCAD', 60).show()

# %% [markdown]
# Interpret the FX quote carefully: negative USD/CAD returns mean CAD appreciation. A negative WTI/USD-CAD correlation therefore aligns rising oil with a stronger Canadian dollar.
